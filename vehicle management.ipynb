# %%
import json
import requests
import pandas as pd
pd.options.display.max_columns = 50

# %%
params = {
    'login': 'ionesantos',
    'senha': '2022Power'
}

url = "https://webfleet.pointerbrasil.com.br/FleetAPI/api"

# %%
url = f"https://webfleet.pointerbrasil.com.br/FleetAPI/api/Login/Get?username={params['login']}&password={params['senha']}"
x = requests.get(url, verify=False)
print(x.headers)
y = x.json()
print(y)
print(url)
# Out:
# C:\Users\MarkosPereira.exc\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webfleet.pointerbrasil.com.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'Server': 'rhino-core-shield', 'Date': 'Wed, 20 Sep 2023 13:17:06 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, must-revalidate, max-age=1', 'Set-Cookie': 'ASP.NET_SessionId=xztkw12kt4s4g4vztpaa2yjd; path=/; HttpOnly; SameSite=Lax, GCLB=CNymk5KfgbaDvwE; path=/; HttpOnly', 'X-AspNet-Version': '4.0.30319', 'X-Powered-By': 'ASP.NET', 'Via': '1.1 google', 'Alt-Svc': 'clear', 'Content-Length': '78'}
# {'Version': '1.0.61.0', 'StatusCode': 200, 'Result': {'Token': '97823030520000039'}}
# https://webfleet.pointerbrasil.com.br/FleetAPI/api/Login/Get?username=ionesantos&password=2022Power

# %%
token = y['Result']['Token']
print(token)
# Out:
# 97823030520000039

# %% [markdown]
# ## Get vehicles

# %%
url = f"https://webfleet.pointerbrasil.com.br/FleetAPI/api/Vehicle/GetVehicles?key={token}"

x = requests.get(url, verify=False)
print(x.headers)
print(url)
y = x.json()
print(y)
# Out:
# C:\Users\MarkosPereira.exc\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webfleet.pointerbrasil.com.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'Server': 'rhino-core-shield', 'Date': 'Wed, 20 Sep 2023 13:17:09 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Vary': 'Accept-Encoding', 'Cache-Control': 'no-cache', 'Pragma': 'no-cache', 'Expires': '-1', 'Set-Cookie': 'ASP.NET_SessionId=03kfjzphhtynglorkvkvrti1; path=/; HttpOnly; SameSite=Lax, GCLB=CO712vC40cvj5wE; path=/; HttpOnly', 'X-AspNet-Version': '4.0.30319', 'X-Powered-By': 'ASP.NET', 'Content-Encoding': 'gzip', 'Via': '1.1 google', 'Alt-Svc': 'clear', 'Content-Length': '34923'}
# https://webfleet.pointerbrasil.com.br/FleetAPI/api/Vehicle/GetVehicles?key=97823030520000039
# ...

# %%
VehicleId = list()
ExternalVehicleId = list()
LicencePlate = list()
FleetNumber = list()
FleetAlias = list()
UnitSysId = list()
ColorId = list()
ProducerId = list()
ModelId = list()
GroupId = list()
IconId = list()
ConfigurationId = list()
SAList = list()


values = y['Result']['Vehicles']


for value in values:
    VehicleId.append(value['VehicleId'])
    ExternalVehicleId.append(value['ExternalVehicleId'])
    LicencePlate.append(value['LicencePlate'])
    FleetNumber.append(value['FleetNumber'])
    FleetAlias.append(value['FleetAlias'])
    UnitSysId.append(value['UnitSysId'])
    ColorId.append(value['ColorId'])
    ProducerId.append(value['ProducerId'])
    ModelId.append(value['ModelId'])
    GroupId.append(value['GroupId'])
    IconId.append(value['IconId'])
    ConfigurationId.append(value['ConfigurationId'])
    SAList.append(value['SAList'])

veicles = pd.DataFrame({'VehicleId':VehicleId, 'ExternalVehicleId': ExternalVehicleId, 'LicencePlate': LicencePlate,
                        'FleetNumber': FleetNumber, 'FleetAlias': FleetAlias, 'UnitSysId': UnitSysId,
                        'ColorId': ColorId, 'ProducerId': ProducerId, 'ModelId': ModelId, 'GroupId': GroupId,
                        'IconId': IconId, 'ConfigurationId': ConfigurationId, 'SAList': SAList})
veicles
# Out:
#       VehicleId  ExternalVehicleId LicencePlate FleetNumber FleetAlias  \
# 0        173449                  0      QXE0399     QXE0399    QXE0399
# 1        173722                  0      QXG6865        None       None
# 2        173724                  0      QXG6870        None       None
# 3        173726                  0      QXG6869        None       None
# 4        173729                  0      QXG6871        None       None
# ...         ...                ...          ...         ...        ...
# 1586     211673                  0      RVS0J23     2227535    2227535
# 1587     211852                  0      QVU9J17     QVU9J17    QVU9J17
# 1588     212327                  0      RVU3J26     2294506    2294506
# 1589     212740                  0      RVX1C94     2293891    2293891
# 1590     212874                  0      RVV6H25     2170343    2170343
#
#       UnitSysId  ColorId  ProducerId  ModelId  GroupId  IconId  \
# ...

# %% [markdown]
# ## Get fuel types

# %%
url = f"https://webfleet.pointerbrasil.com.br/FleetAPI/api/Vehicle/GetFuelTypes?key={token}"

x = requests.get(url, verify=False)
print(x.headers)
print(url)
y = x.json()
print(y)
# Out:
# C:\Users\MarkosPereira.exc\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webfleet.pointerbrasil.com.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'Server': 'rhino-core-shield', 'Date': 'Wed, 20 Sep 2023 13:17:11 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'no-cache', 'Pragma': 'no-cache', 'Expires': '-1', 'Set-Cookie': 'ASP.NET_SessionId=0vlrwtijdu0rnendbjqv3fn1; path=/; HttpOnly; SameSite=Lax, GCLB=CJnLqISu3bucVg; path=/; HttpOnly', 'X-AspNet-Version': '4.0.30319', 'X-Powered-By': 'ASP.NET', 'Via': '1.1 google', 'Alt-Svc': 'clear', 'Content-Length': '360'}
# https://webfleet.pointerbrasil.com.br/FleetAPI/api/Vehicle/GetFuelTypes?key=97823030520000039
# ...

# %%
Id = list()
ExternalId = list()
Name = list()

values = y['Result']['FuelTypes']


for value in values:
    Id.append(value['Id'])
    ExternalId.append(value['ExternalId'])
    Name.append(value['Name'])
    
    
fueltypes = pd.DataFrame({'Id': Id, 'ExternalId': ExternalId, 'Name': Name})
fueltypes
# Out:
#    Id  ExternalId                    Name
# 0   1           0                  Diesel
# 1   2           0                Gasolina
# 2   3           0                  Etanol
# 3   4           0                     Gás
# 4  12           0                    Flex
# 5  13           0                    Flex
# 6  17           0  Gasolina e Gás Natural

# %% [markdown]
# ## Get vehicle type

# %%
url = f"https://webfleet.pointerbrasil.com.br/FleetAPI/api/Vehicle/GetVehicleTypes?key={token}"

x = requests.get(url, verify=False)
print(x.headers)
print(url)
y = x.json()
print(y)
# Out:
# C:\Users\MarkosPereira.exc\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webfleet.pointerbrasil.com.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'Server': 'rhino-core-shield', 'Date': 'Wed, 20 Sep 2023 13:17:12 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'no-cache', 'Pragma': 'no-cache', 'Expires': '-1', 'Set-Cookie': 'ASP.NET_SessionId=3qbjez1nit2tsgxzbvwlxwwk; path=/; HttpOnly; SameSite=Lax, GCLB=CP2M-962naOysAE; path=/; HttpOnly', 'X-AspNet-Version': '4.0.30319', 'X-Powered-By': 'ASP.NET', 'Via': '1.1 google', 'Alt-Svc': 'clear', 'Content-Length': '68'}
# https://webfleet.pointerbrasil.com.br/FleetAPI/api/Vehicle/GetVehicleTypes?key=97823030520000039
# {'Version': '1.0.61.0', 'StatusCode': 200, 'Result': {'VehicleTypes': []}}

# %% [markdown]
# ## Get vehicle information

# %%
url = f"https://webfleet.pointerbrasil.com.br/FleetAPI/api/Vehicle/GetVehiclesInfo?key={token}"

url = f'https://webfleet.pointerbrasil.com.br/FleetAPI/api/Vehicle/GetVehiclesInfo&key=
FleetAPI/api/Vehicle/GetVehiclesInfo?
x = requests.get(url, verify=False)
print(x.headers)
print(url)
y = x.json()
print(y)
# Out:
# Object `GetVehiclesInfo` not found.
# C:\Users\MarkosPereira.exc\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webfleet.pointerbrasil.com.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'Server': 'rhino-core-shield', 'Date': 'Wed, 20 Sep 2023 13:17:23 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Vary': 'Accept-Encoding', 'Cache-Control': 'no-cache', 'Pragma': 'no-cache', 'Expires': '-1', 'Set-Cookie': 'ASP.NET_SessionId=e3gvrhasya222mbpehec0xx1; path=/; HttpOnly; SameSite=Lax, GCLB=CL3NwNS-wsyyEg; path=/; HttpOnly', 'X-AspNet-Version': '4.0.30319', 'X-Powered-By': 'ASP.NET', 'Content-Encoding': 'gzip', 'Via': '1.1 google', 'Alt-Svc': 'clear', 'Content-Length': '117495'}
# https://webfleet.pointerbrasil.com.br/FleetAPI/api/Vehicle/GetVehiclesInfo?key=97823030520000039
# ...

# %%
y['Result'].keys()
# Out:
# dict_keys(['22699_16. Suzano', '22699_Unidade Imperatiz', '22699_Unidade Limeira', '22699_Unidade Suzano', '22699_Unidade Jacareí', '22699_Unidade Mucuri', '22699_Unidade Aracruz', '22699_Unidade Três Lagoas', '22699_Unidade Ribas do Rio Pardo', '22699_01.Expresso Nepomuceno', '22699_UNIDADE  INSTITUTO ECOFUTURO  BERTIOGA', '22699_UNIDADE  ITAPETININGA'])

# %%
y['Result']
# Out:
# {'22699_16. Suzano': [{'ExternalId': 0,
#    'Direction': 329,
#    'AccountID': 22699,
#    'GroupId': 96846,
#    'AccountName': '16.Suzano',
#    'UnitID': 284220170,
#    'LicensePlate': 'QVU9J97',
#    'FleetAlias': '2342201',
#    'FleetNumber': '2342201',
#    'FuelType': 1,
#    'Manufacturer': 'Toyota              ',
#    'Model': 'Hilux               ',
#    'Year': None,
#    'VehicleID': 204896,
#    'LastMessageTime': '19/09/2023 15:26:08',
#    'LastLocationTime': '19/09/2023 15:26:08',
#    'Lat': -20.729248,
#    'Long': -51.741755,
#    'Address': 'RODOVIA BR-158, 7KM DE TRES LAGOAS, MS',
#    'Speed': 85,
#    'Battery': 13.76,
#    'Ignition': 1,
#    'DriverName': 'ANDRESON DOS SANTOS  ',
#    'Odometer': 59659,
#    'IOData': {'Inputs': [{'Name': 'Ignição', 'Value': 'Ligado'},
#      {'Name': 'Limpador do Para-brisa', 'Value': 'Desligado'}],
#     'Outputs': [{'Name': 'Sirene', 'Value': 'Inativa'}]}},
#   {'ExternalId': 0,
#    'Direction': 209,
# ...

# %%
y['Result']['22699_01.Expresso Nepomuceno']
# Out:
# [{'ExternalId': 0,
#   'Direction': 169,
#   'AccountID': 22699,
#   'GroupId': 150519,
#   'AccountName': '16.Suzano',
#   'UnitID': 280596570,
#   'LicensePlate': 'RVX1D55',
#   'FleetAlias': 'RVX1D55',
#   'FleetNumber': 'RVX1D55',
#   'FuelType': 1,
#   'Manufacturer': 'Toyota              ',
#   'Model': None,
#   'Year': None,
#   'VehicleID': 208681,
#   'LastMessageTime': '19/09/2023 15:17:54',
#   'LastLocationTime': '19/09/2023 15:17:54',
#   'Lat': -20.46362,
#   'Long': -53.759733,
#   'Address': 'AV AURELIANO MOURA BRANDAO, 2071-2103, RIBAS DO RIO PARDO, MS',
#   'Speed': 0,
#   'Battery': 13.05,
#   'Ignition': 0,
#   'DriverName': None,
#   'Odometer': 27023,
#   'IOData': {'Inputs': [{'Name': 'Ignição', 'Value': 'Desligado'},
#     {'Name': 'Limpador do Para-brisa', 'Value': 'Desligado'}],
#    'Outputs': [{'Name': 'Sirene', 'Value': 'Inativa'}]}}]

# %%
df_arq_cap = list()

for key in y['Result'].keys():
    element = y['Result'][key]
    
    ExternalId, Direction, AccountID, GroupId, AccountName, UnitID = list(), list(), list(), list(), list(), list()
    LicensePlate, FleetAlias, FleetNumber, FuelType, Manufacturer, Model = list(), list(), list(), list(), list(), list()
    Year, VehicleID, LastMessageTime, LastLocationTime, Lat, Long = list(), list(), list(), list(), list(), list()
    Address, Speed, Battery, Ignition, DriverName, Odometer = list(), list(), list(), list(), list(), list()
    IOData_input_name, IOData_input_value, IOData_name, IOData_value = list(), list(), list(), list()
    IOData_output_name, IOData_output_value = list(), list()
    

    for value in element:
        ExternalId.append(value['ExternalId'])
        Direction.append(value['Direction'])
        AccountID.append(value['AccountID'])
        GroupId.append(value['GroupId'])
        AccountName.append(value['AccountName'])
        UnitID.append(value['UnitID'])
        LicensePlate.append(value['LicensePlate'])
        FleetAlias.append(value['FleetAlias'])
        FleetNumber.append(value['FleetNumber'])
        FuelType.append(value['FuelType'])
        Manufacturer.append(value['Manufacturer'])
        Model.append(value['Model'])
        Year.append(value['Year'])
        VehicleID.append(value['VehicleID'])
        LastMessageTime.append(value['LastMessageTime'])
        LastLocationTime.append(value['LastLocationTime'])
        Lat.append(value['Lat'])
        Long.append(value['Long'])
        Address.append(value['Address'])
        Speed.append(value['Speed'])
        Battery.append(value['Battery'])
        Ignition.append(value['Ignition'])
        DriverName.append(value['DriverName'])
        Odometer.append(value['Odometer'])
#         IOData_input_name.append(value['IOData']['Inputs'][0]['Name'])
#         IOData_input_value.append(value['IOData']['Inputs'][0]['Value'])
#         IOData_name.append(value['IOData']['Inputs'][1]['Name'])
#         IOData_value.append(value['IOData']['Inputs'][1]['Value'])
        
    auxiliar_df = pd.DataFrame({'ExternalId': ExternalId, 'Direction':Direction, 'AccountID':AccountID, 'GroupId':GroupId,
                                'AccountName': AccountName, 'UnitID': UnitID, 'LicensePlate': LicensePlate,
                                'FleetAlias': FleetAlias, 'FleetNumber': FleetNumber, 'FuelType': FuelType,
                                'Manufacturer': Manufacturer, 'Model': Model, 'Year': Year, 'VehicleID': VehicleID,
                                'LastMessageTime': LastMessageTime, 'LastLocationTime': LastLocationTime, 'Lat': Lat,
                                'Long': Long, 'Address': Address, 'Speed':Speed, 'Battery': Battery, 'Ignition': Ignition, 
                                'DriverName': DriverName, 'Odometer': Odometer})
#                                 'Parabrisa': IOData_name, 'Status parabrisa': IOData_value
#                                 'Ignição': IOData_input_name,
#                                 'Status ignção': IOData_input_value

    auxiliar_df = auxiliar_df.assign(origin=key)
    df_arq_cap.append(auxiliar_df)
#         print(value.keys())

# %%
# for df in df_arq_cap:
#     display(df.head(5))
#     print(df.shape)

# %%
vehicle_information = pd.concat(df_arq_cap)
vehicle_information.head(5)
# Out:
#    ExternalId  Direction  AccountID  GroupId AccountName     UnitID  \
# 0           0        329      22699    96846   16.Suzano  284220170
# 1           0        209      22699    96846   16.Suzano  266146670
# 2           0          0      22699    96846   16.Suzano  290892970
# 3           0        105      22699    96846   16.Suzano  284191470
# 4           0         21      22699    96846   16.Suzano  286348770
#
#   LicensePlate FleetAlias FleetNumber  FuelType          Manufacturer  \
# 0      QVU9J97    2342201     2342201         1  Toyota
# 1      QVV4I17    2629288     2629288         1                  None
# 2      QXZ8J37    QXZ8J37     QXZ8J37         1  Acura
# 3      RFC6F16    2341914     2341914         1  Acura
# 4      RFE8D06       None        None         1  Acura
#
#                   Model  Year  VehicleID      LastMessageTime  \
# 0  Hilux                 None     204896  19/09/2023 15:26:08
# 1                  None  None     208302  19/09/2023 15:04:16
# ...

# %% [markdown]
# ## Get Vehicle Route History Information

# %%
url = f"https://webfleet.pointerbrasil.com.br/FleetAPI/api/Vehicle/GetVehicleRouteHistoryInfo?key={token}&StartDate=20230601&EndDate=20230631&LicensePlate=QVU9J97"
x = requests.get(url, verify=False)
print(x.headers)
print(url)
y = x.json()
print(y)
# Out:
# C:\Users\MarkosPereira.exc\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webfleet.pointerbrasil.com.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'Server': 'rhino-core-shield', 'Date': 'Tue, 19 Sep 2023 19:21:39 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'no-cache', 'Pragma': 'no-cache', 'Expires': '-1', 'Set-Cookie': 'ASP.NET_SessionId=l4ji4wwgoygth533ipjpbvu3; path=/; HttpOnly; SameSite=Lax, GCLB=CM6g1oL29pOKhAE; path=/; HttpOnly', 'X-AspNet-Version': '4.0.30319', 'X-Powered-By': 'ASP.NET', 'Via': '1.1 google', 'Alt-Svc': 'clear', 'Content-Length': '116'}
# https://webfleet.pointerbrasil.com.br/FleetAPI/api/Vehicle/GetVehicleRouteHistoryInfo?key=46875907220000050&StartDate=20230601&EndDate=20230631&LicensePlate=QVU9J97
# ...
