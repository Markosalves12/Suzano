# %%
import json
import requests
import pandas as pd
import numpy as np
import os
from datetime import datetime, timedelta
pd.options.display.max_columns = 50

# %%
params = {
    'login': 'ionesantos',
    'senha': '2022Power'
}

url = "https://webfleet.pointerbrasil.com.br/FleetAPI/api"

# %%
url = f"https://webfleet.pointerbrasil.com.br/FleetAPI/api/Login/Get?username={params['login']}&password={params['senha']}"
x = requests.get(url, verify=False)
print(x.headers)
y = x.json()
print(y)
print(url)
# Out:
# C:\Users\MarkosPereira.exc\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webfleet.pointerbrasil.com.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'Server': 'rhino-core-shield', 'Date': 'Mon, 06 Nov 2023 23:01:41 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, must-revalidate, max-age=1', 'Set-Cookie': 'ASP.NET_SessionId=own1qkzvorkk3ikme5svo2tz; path=/; HttpOnly; SameSite=Lax, GCLB=CNyg3tHIuYXAVg; path=/; HttpOnly', 'X-AspNet-Version': '4.0.30319', 'X-Powered-By': 'ASP.NET', 'Via': '1.1 google', 'Alt-Svc': 'clear', 'Content-Length': '78'}
# {'Version': '1.0.61.0', 'StatusCode': 200, 'Result': {'Token': '18491933420000044'}}
# https://webfleet.pointerbrasil.com.br/FleetAPI/api/Login/Get?username=ionesantos&password=2022Power

# %%
token = y['Result']['Token']
print(token)
# Out:
# 18491933420000044

# %% [markdown]
# ## Get vehicles

# %%
url = f"https://webfleet.pointerbrasil.com.br/FleetAPI/api/Vehicle/GetVehicles?key={token}"

x = requests.get(url, verify=False)
print(x.headers)
print(url)
y = x.json()
print(y)
# Out:
# C:\Users\MarkosPereira.exc\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webfleet.pointerbrasil.com.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'Server': 'rhino-core-shield', 'Date': 'Mon, 06 Nov 2023 23:01:42 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Vary': 'Accept-Encoding', 'Cache-Control': 'no-cache', 'Pragma': 'no-cache', 'Expires': '-1', 'Set-Cookie': 'ASP.NET_SessionId=uxcb1vh1xloouj1cwoj4m4nv; path=/; HttpOnly; SameSite=Lax, GCLB=CK2-nP6Zh7PNuwE; path=/; HttpOnly', 'X-AspNet-Version': '4.0.30319', 'X-Powered-By': 'ASP.NET', 'Content-Encoding': 'gzip', 'Via': '1.1 google', 'Alt-Svc': 'clear', 'Content-Length': '33255'}
# https://webfleet.pointerbrasil.com.br/FleetAPI/api/Vehicle/GetVehicles?key=18491933420000044
# ...

# %%
caminho_get_vehivle = r"C:\Users\MarkosPereira.exc\Suzano S A\Gestão Facilities Brasil - Pointer\Dados da API\Vehicle Management\GetVehicles.xlsx".replace("\\","/")

VehicleId = list()
ExternalVehicleId = list()
LicencePlate = list()
FleetNumber = list()
FleetAlias = list()
UnitSysId = list()
ColorId = list()
ProducerId = list()
ModelId = list()
GroupId = list()
IconId = list()
ConfigurationId = list()
SAList = list()


values = y['Result']['Vehicles']


for value in values:
    VehicleId.append(value['VehicleId'])
    ExternalVehicleId.append(value['ExternalVehicleId'])
    LicencePlate.append(value['LicencePlate'])
    FleetNumber.append(value['FleetNumber'])
    FleetAlias.append(value['FleetAlias'])
    UnitSysId.append(value['UnitSysId'])
    ColorId.append(value['ColorId'])
    ProducerId.append(value['ProducerId'])
    ModelId.append(value['ModelId'])
    GroupId.append(value['GroupId'])
    IconId.append(value['IconId'])
    ConfigurationId.append(value['ConfigurationId'])
    SAList.append(value['SAList'])

veicles = pd.DataFrame({'VehicleId':VehicleId, 'ExternalVehicleId': ExternalVehicleId, 'LicencePlate': LicencePlate,
                        'FleetNumber': FleetNumber, 'FleetAlias': FleetAlias, 'UnitSysId': UnitSysId,
                        'ColorId': ColorId, 'ProducerId': ProducerId, 'ModelId': ModelId, 'GroupId': GroupId,
                        'IconId': IconId, 'ConfigurationId': ConfigurationId, 'SAList': SAList})

veicles.to_excel(caminho_get_vehivle, index=False)

veicles
# Out:
#       VehicleId  ExternalVehicleId LicencePlate FleetNumber FleetAlias  \
# 0        173722                  0      QXG6865        None       None
# 1        173724                  0      QXG6870        None       None
# 2        173726                  0      QXG6869        None       None
# 3        173729                  0      QXG6871        None       None
# 4        173730                  0      QXG6872        None       None
# ...         ...                ...          ...         ...        ...
# 1483     211673                  0      RVS0J23     2227535    2227535
# 1484     211852                  0      QVU9J17     QVU9J17    QVU9J17
# 1485     212327                  0      RVU3J26     2294506    2294506
# 1486     212740                  0      RVX1C94     2293891    2293891
# 1487     212874                  0      RVV6H25     2170343    2170343
#
#       UnitSysId  ColorId  ProducerId  ModelId  GroupId  IconId  \
# ...

# %% [markdown]
# ## Get fuel types

# %%
url = f"https://webfleet.pointerbrasil.com.br/FleetAPI/api/Vehicle/GetFuelTypes?key={token}"

x = requests.get(url, verify=False)
print(x.headers)
print(url)
y = x.json()
print(y)
# Out:
# C:\Users\MarkosPereira.exc\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webfleet.pointerbrasil.com.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'Server': 'rhino-core-shield', 'Date': 'Mon, 06 Nov 2023 23:01:43 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'no-cache', 'Pragma': 'no-cache', 'Expires': '-1', 'Set-Cookie': 'ASP.NET_SessionId=4nb4nbakw1p3e1mjhe0jlqzr; path=/; HttpOnly; SameSite=Lax, GCLB=CObn75-Il57QxAE; path=/; HttpOnly', 'X-AspNet-Version': '4.0.30319', 'X-Powered-By': 'ASP.NET', 'Via': '1.1 google', 'Alt-Svc': 'clear', 'Content-Length': '360'}
# https://webfleet.pointerbrasil.com.br/FleetAPI/api/Vehicle/GetFuelTypes?key=18491933420000044
# ...

# %%
caminho_fuel_types = r"C:\Users\MarkosPereira.exc\Suzano S A\Gestão Facilities Brasil - Pointer\Dados da API\Vehicle Management\GetFuelTypes.xlsx".replace("\\","/")

Id = list()
ExternalId = list()
Name = list()

values = y['Result']['FuelTypes']


for value in values:
    Id.append(value['Id'])
    ExternalId.append(value['ExternalId'])
    Name.append(value['Name'])
    
    
fueltypes = pd.DataFrame({'Id': Id, 'ExternalId': ExternalId, 'Name': Name})
fueltypes.to_excel(caminho_fuel_types, index=False)
fueltypes
# Out:
#    Id  ExternalId                    Name
# 0   1           0                  Diesel
# 1   2           0                Gasolina
# 2   3           0                  Etanol
# 3   4           0                     Gás
# 4  12           0                    Flex
# 5  13           0                    Flex
# 6  17           0  Gasolina e Gás Natural

# %% [markdown]
# ## Get Vehicle Icons

# %%
url = f"https://webfleet.pointerbrasil.com.br/FleetAPI/api/Vehicle/GetVehicleIcons?key={token}"

x = requests.get(url, verify=False)
print(x.headers)
print(url)
y = x.json()
print(y)
# Out:
# C:\Users\MarkosPereira.exc\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webfleet.pointerbrasil.com.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'Server': 'rhino-core-shield', 'Date': 'Mon, 06 Nov 2023 23:01:43 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Vary': 'Accept-Encoding', 'Cache-Control': 'no-cache', 'Pragma': 'no-cache', 'Expires': '-1', 'Set-Cookie': 'ASP.NET_SessionId=s0uhwtftpbdfdhug3bb0ya4v; path=/; HttpOnly; SameSite=Lax, GCLB=CIjZ5NXwpt2z2gE; path=/; HttpOnly', 'X-AspNet-Version': '4.0.30319', 'X-Powered-By': 'ASP.NET', 'Content-Encoding': 'gzip', 'Via': '1.1 google', 'Alt-Svc': 'clear', 'Content-Length': '651'}
# https://webfleet.pointerbrasil.com.br/FleetAPI/api/Vehicle/GetVehicleIcons?key=18491933420000044
# ...

# %%
values = y['Result']['VehicleIcons']

# %%
caminho_vehicle_icon = r"C:\Users\MarkosPereira.exc\Suzano S A\Gestão Facilities Brasil - Pointer\Dados da API\Vehicle Management\GetVehicleIcons.xlsx".replace("\\","/")

IconId = list()
Name = list()
description = list()
IsDefault = list()
IconType = list()
IsNew = list()

for value in values:
    IconId.append(value['IconId'])
    Name.append(value['Name'])
    description.append(value['description'])
    IsDefault.append(value['IsDefault'])
    IconType.append(value['IconType'])
    IsNew.append(value['IsNew'])
    
    
vehicle_icon = pd.DataFrame({'IconId': IconId, 'Name': Name, 'description': description, 'IsDefault': IsDefault,
                             'IconType': IconType, 'IsNew': IsNew})
vehicle_icon.to_excel(caminho_vehicle_icon, index=False)
vehicle_icon
# Out:
#     IconId                       Name description  IsDefault  IconType  IsNew
# 0     4091                    2pickup        None      False         1  False
# 1     4079               2reboqueleve        None      False         1  False
# 2     4080                       2van        None      False         1  False
# 3     4036                       320D        None      False         1  False
# 4     4042  DoubleDrumVibratoryRoller        None      False         1  False
# 5     4044                DumperTruck        None      False         1  False
# 6     4043              FellerBuncher        None      False         1  False
# 7     4045                        Hex        None      False         1  False
# 8     4047           IndustrialLoader        None      False         1  False
# 9     4046                MotorGrader        None      False         1  False
# 10    4056                  Pipelayer        None      False         1  False
# ...

# %% [markdown]
# ## Get vehicle information

# %%
url = f"https://webfleet.pointerbrasil.com.br/FleetAPI/api/Vehicle/GetVehiclesInfo?key={token}"

x = requests.get(url, verify=False)
print(x.headers)
print(url)
y = x.json()
print(y)
# Out:
# C:\Users\MarkosPereira.exc\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webfleet.pointerbrasil.com.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'Server': 'rhino-core-shield', 'Date': 'Mon, 06 Nov 2023 23:01:47 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Vary': 'Accept-Encoding', 'Cache-Control': 'no-cache', 'Pragma': 'no-cache', 'Expires': '-1', 'Set-Cookie': 'ASP.NET_SessionId=h4sze0rd1pndakynnr03gjqe; path=/; HttpOnly; SameSite=Lax, GCLB=CLHJnuP2oeWwMw; path=/; HttpOnly', 'X-AspNet-Version': '4.0.30319', 'X-Powered-By': 'ASP.NET', 'Content-Encoding': 'gzip', 'Via': '1.1 google', 'Alt-Svc': 'clear', 'Content-Length': '111853'}
# https://webfleet.pointerbrasil.com.br/FleetAPI/api/Vehicle/GetVehiclesInfo?key=18491933420000044
# ...

# %%
import pandas as pd

def convert_dict_to_table(data_dict):
    # Extrair os valores desejados de 'IOData' 'Inputs'
    inputs = data_dict.get('IOData', {}).get('Inputs', [])
    input_dict = {entry['Name']: entry['Value'] for entry in inputs}
    
    # Extrair os valores desejados de 'IOData' 'Outputs'
    outputs = data_dict.get('IOData', {}).get('Outputs', [])
    output_dict = {entry['Name']: entry['Value'] for entry in outputs}
    
    # Criar um DataFrame pandas
    df = pd.DataFrame({
        'ExternalId': [data_dict.get('ExternalId')],
        'Direction': [data_dict.get('Direction')],
        'AccountID': [data_dict.get('AccountID')],
        'GroupId': [data_dict.get('GroupId')],
        'AccountName': [data_dict.get('AccountName')],
        'UnitID': [data_dict.get('UnitID')],
        'LicensePlate': [data_dict.get('LicensePlate')],
        'FleetAlias': [data_dict.get('FleetAlias')],
        'FleetNumber': [data_dict.get('FleetNumber')],
        'FuelType': [data_dict.get('FuelType')],
        'Manufacturer': [data_dict.get('Manufacturer')],
        'Model': [data_dict.get('Model')],
        'Year': [data_dict.get('Year')],
        'VehicleID': [data_dict.get('VehicleID')],
        'LastMessageTime': [data_dict.get('LastMessageTime')],
        'LastLocationTime': [data_dict.get('LastLocationTime')],
        'Lat': [data_dict.get('Lat')],
        'Long': [data_dict.get('Long')],
        'Address': [data_dict.get('Address')],
        'Speed': [data_dict.get('Speed')],
        'Battery': [data_dict.get('Battery')],
        'Ignition': [data_dict.get('Ignition')],
        'DriverName': [data_dict.get('DriverName')],
        'Odometer': [data_dict.get('Odometer')],
        'Ignição': [input_dict.get('Ignição', None)],
        'Limpador do Para-brisa': [input_dict.get('Limpador do Para-brisa', None)],
        'Sirene': [output_dict.get('Sirene', None)]
    })
    
    return df

# %%
df_arq_cap = list()

for key in y['Result'].keys():
    element = y['Result'][key]
    
    for value in element:
        df = convert_dict_to_table(value)
        df = df.assign(origin=key)
        df_arq_cap.append(df)

# %%
caminho_vehicle_information = r"C:\Users\MarkosPereira.exc\Suzano S A\Gestão Facilities Brasil - Pointer\Dados da API\Vehicle Management\GetVehiclesInfo.xlsx".replace("\\","/")
vehicle_information = pd.concat(df_arq_cap)
vehicle_information.to_excel(caminho_vehicle_information, index=False)
vehicle_information.head(5)
# Out:
#    ExternalId  Direction  AccountID  GroupId AccountName     UnitID  \
# 0           0         74      22699    96846   16.Suzano  284220170
# 0           0         32      22699    96846   16.Suzano  266146670
# 0           0          0      22699    96846   16.Suzano  290892970
# 0           0         57      22699    96846   16.Suzano  277836670
# 0           0        334      22699    96846   16.Suzano  265495070
#
#   LicensePlate FleetAlias FleetNumber  FuelType          Manufacturer  \
# 0      QVU9J97    2342201     2342201         1  Toyota
# 0      QVV4I17    2629288     2629288         1                  None
# 0      QXZ8J37    QXZ8J37     QXZ8J37         1  Acura
# 0      RGA2J68    2278366     2278366         1  Acura
# 0      RMJ2H25    RMJ2H25     RMJ2H25         1  Acura
#
#                   Model  Year  VehicleID      LastMessageTime  \
# 0  Hilux                 None     204896  03/11/2023 20:06:16
# 0                  None  None     208302  06/11/2023 19:59:13
# ...

# %% [markdown]
# ## Get Daily Activity

# %%
def dividir_e_salvar_dataframe(df, diretorio, string):
    # Verifique o tamanho do DataFrame
    num_linhas = len(df)

    if num_linhas > 1000000:
        # Divida o DataFrame em partes menores de 1 milhão de linhas
        num_partes = (num_linhas // 1000000) + 1

        for i, chunk in enumerate(np.array_split(df, num_partes)):
            # Crie o nome do arquivo com base na string e no índice
            nome_arquivo = f"{string}_{i + 1}.xlsx"
            caminho_arquivo = os.path.join(diretorio, nome_arquivo)

            # Salve o chunk como um arquivo CSV com os cabeçalhos
            chunk.to_excel(caminho_arquivo, index=False)

    else:
        # Se o DataFrame for pequeno, salve-o como um único arquivo
        nome_arquivo = f"{string}.xlsx"
        caminho_arquivo = os.path.join(diretorio, nome_arquivo)
        df.to_excel(caminho_arquivo, index=False)

# %%
import json
import requests
import pandas as pd

params = {
    'login': 'ionesantos',
    'senha': '2022Power'
}

# login na API
url = f"https://webfleet.pointerbrasil.com.br/FleetAPI/api/Login/Get?username={params['login']}&password={params['senha']}"
x = requests.get(url, verify=False)
y = x.json()
token = y['Result']['Token']

# Get vehicles
url = f"https://webfleet.pointerbrasil.com.br/FleetAPI/api/Vehicle/GetVehicles?key={token}"
x = requests.get(url, verify=False)
y = x.json()

VehicleId = list()
LicencePlate = list()

values = y['Result']['Vehicles']

for value in values:
    VehicleId.append(value['VehicleId'])
    LicencePlate.append(value['LicencePlate'])

vehicles = pd.DataFrame({'VehicleId':VehicleId, 'LicencePlate': LicencePlate}).drop_duplicates().sort_values('VehicleId', ascending=False)

def def_convert_daily_activity(daily_activity):
    ExternalVehicleId = list()
    VehicleId = list()
    LicensePlate = list()
    FleetAlias = list()
    GroupId = list()
    DriverName = list()
    DriverId = list()
    ExternalDriverId = list()
    DateTime = list()
    TotalDistance = list()
    MaxSpeed = list()
    AvgSpeed = list()
    NumbreOfStops = list()
    NumberOfGeoFences = list()
    IdlingDuration = list()
    ParkingDuration = list()
    DrivingDuration = list()
    HourMeter = list()

    for value in values:
        ExternalVehicleId.append(value['ExternalVehicleId'])
        VehicleId.append(value['VehicleId'])
        LicensePlate.append(value['LicensePlate'])
        FleetAlias.append(value['FleetAlias'])
        GroupId.append(value['GroupId'])
        DriverName.append(value['DriverName'])
        DriverId.append(value['DriverId'])
        ExternalDriverId.append(value['ExternalDriverId'])
        DateTime.append(value['DateTime'])
        TotalDistance.append(value['TotalDistance'])
        MaxSpeed.append(value['MaxSpeed'])
        AvgSpeed.append(value['AvgSpeed'])
        NumbreOfStops.append(value['NumbreOfStops'])
        NumberOfGeoFences.append(value['NumberOfGeoFences'])
        IdlingDuration.append(value['IdlingDuration'])
        ParkingDuration.append(value['ParkingDuration'])
        DrivingDuration.append(value['DrivingDuration'])
        HourMeter.append(value['HourMeter'])

    df = pd.DataFrame({'ExternalVehicleId':ExternalVehicleId, 'VehicleId':VehicleId, 'LicensePlate':LicensePlate,
                       'FleetAlias':FleetAlias, 'GroupId':GroupId, 'DriverName':DriverName, 'DriverId':DriverId,
                       'ExternalDriverId':ExternalDriverId, 'DateTime':DateTime, 'TotalDistance':TotalDistance,
                       'MaxSpeed':MaxSpeed, 'AvgSpeed':AvgSpeed, 'NumbreOfStops':NumbreOfStops,
                       'NumberOfGeoFences':NumberOfGeoFences, 'IdlingDuration':IdlingDuration,
                       'ParkingDuration':ParkingDuration, 'DrivingDuration':DrivingDuration,
                       'HourMeter': HourMeter})
    return df
# Out:
# C:\Users\MarkosPereira.exc\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webfleet.pointerbrasil.com.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\MarkosPereira.exc\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'webfleet.pointerbrasil.com.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
vehicles[veicles['LicencePlate']=='RMW7E78']
# Out:
# C:\Users\MarkosPereira.exc\AppData\Local\Temp\ipykernel_27532\1970163319.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   vehicles[veicles['LicencePlate']=='RMW7E78']
#      VehicleId LicencePlate
# 294     191523      RMW7E78

# %%
# for i in vehicles.index:
#     url = f"https://webfleet.pointerbrasil.com.br/FleetAPI/api/Vehicle/GetDailyActivity?key={token}&StartDate=2023/09/01&EndDate=2023/09/30&LicensePlate={vehicles.iloc[i][1]}&VehicleIds={vehicles.iloc[i][0]}"
#     x = requests.get(url, verify=False)
#     y = x.json()

#     try:
#         df_arc_cap = list()
#         values = y['Result']

#         for value in values:
#             df = def_convert_daily_activity(value)
#             df_arc_cap.append(df)

#         daily_activity = pd.concat(df_arc_cap)
#         daily_activity = daily_activity.drop_duplicates()
#         caminho_GetDailyActivity = r"C:\Users\MarkosPereira.exc\Suzano S A\Gestão Facilities Brasil - Pointer\Dados da API\Vehicle Management\GetDailyActivity_setembro".replace("\\","/")
#         dividir_e_salvar_dataframe(daily_activity, caminho_GetDailyActivity, f"GetDailyActivity_{vehicles.iloc[i][1]}_{vehicles.iloc[i][0]}")
    
#     except:
#         continue

# %%
def lista_de_datas(data_inicio, data_final):
    # Converte as datas de entrada para objetos datetime
    data_inicio = datetime.strptime(data_inicio, '%Y/%m/%d')
    data_final = datetime.strptime(data_final, '%Y/%m/%d')

    # Inicializa a lista de datas
    datas = []

    # Adiciona as datas à lista enquanto a data de início for menor ou igual à data final
    while data_inicio <= data_final:
        datas.append(data_inicio.strftime('%Y/%m/%d'))
        data_inicio += timedelta(days=1)

    return datas

# %%
def convert_history_rout(values):
    DriverId = list()
    DateTime = list()
    TxReason = list()
    GroupId = list()
    UnitID = list()
    LicensePlate = list()
    VehicleID = list()
    Lat = list()
    Long = list()
    Address = list()
    Speed = list()
    Ignition = list()
    DriverName = list()


    for value in values:
        DriverId.append(value['DriverId'])
        DateTime.append(value['DateTime'])
        TxReason.append(value['TxReason'])
        GroupId.append(value['GroupId'])
        UnitID.append(value['UnitID'])
        LicensePlate.append(value['LicensePlate'])
        VehicleID.append(value['VehicleID'])
        Lat.append(value['Lat'])
        Long.append(value['Long'])
        Address.append(value['Address'])
        Speed.append(value['Speed'])
        Ignition.append(value['Ignition'])
        DriverName.append(value['DriverName'])


    GetVehicleRouteHistoryInfo = pd.DataFrame({'DriverId': DriverId, 'DateTime': DateTime, 'TxReason': TxReason,
                                              'GroupId': GroupId, 'UnitID': UnitID, 'LicensePlate': LicensePlate,
                                              'VehicleID': VehicleID, 'Lat': Lat, 'Long': Long, 'Address': Address,
                                              'Speed': Speed, 'Ignition': Ignition,
                                               'DriverName': DriverName}).drop_duplicates()

    GetVehicleRouteHistoryInfo = GetVehicleRouteHistoryInfo[(GetVehicleRouteHistoryInfo['Lat']!=0)
                                                            &(GetVehicleRouteHistoryInfo['Long']!=0)]
    
    return GetVehicleRouteHistoryInfo

# %%
diretorio = r'C:\Users\MarkosPereira.exc\Suzano S A\Gestão Facilities Brasil - Pointer\Dados da API\Vehicle Management\GetVehicleRouteHistoryInfo_2023\GetVehicleRouteHistoryInfo_outubro'.replace("\\","/")  # Substitua pelo caminho do diretório desejado

arq_in_diretorio = list()
for raiz, diretorios, arquivos in os.walk(diretorio):
    for arquivo in arquivos:
        arq_in_diretorio.append(int(arquivo[-11:-5]))

# %%
vehicles = vehicles.drop(index=vehicles[vehicles['VehicleId'].isin(arq_in_diretorio)].index)
vehicles = vehicles.reset_index().drop(columns='index', axis=1)
vehicles
# Out:
# Empty DataFrame
# Columns: [VehicleId, LicencePlate]
# Index: []

# %%
datas = lista_de_datas('2023/10/01', '2023/10/31')

# %%
p = 0
for i in vehicles.index:
    df_arc_cap = list()
    for data in datas:
        url = f"https://webfleet.pointerbrasil.com.br/FleetAPI/api/Vehicle/GetVehicleRouteHistoryInfo?key={token}&StartDate={data} 00:00:00&EndDate={data} 23:59:59&LicensePlate={vehicles.iloc[i][1]}&VehicleId={vehicles.iloc[i][0]}"
        x = requests.get(url, verify=False)
        y = x.json()
        values = y['Result']
        df = convert_history_rout(values)
        df_arc_cap.append(df)
            
    try: 
        GetVehicleRouteHistoryInfo = pd.concat(df_arc_cap)
    except:
        continue
        
    caminho_GetVehicleRouteHistoryInfo = diretorio
    dividir_e_salvar_dataframe(GetVehicleRouteHistoryInfo, caminho_GetVehicleRouteHistoryInfo, f"GetVehicleRouteHistoryInfo_{vehicles.iloc[i][1]}_{vehicles.iloc[i][0]}")
    p+=1
    
    if p == 5:
        url = f"https://webfleet.pointerbrasil.com.br/FleetAPI/api/Login/Get?username={params['login']}&password={params['senha']}"
        x = requests.get(url, verify=False)
        y = x.json()

        token = y['Result']['Token']

        p = 0
